# %%
# Our previous model was using ALS with Pyspark. Here we take the approach of using other matrix factorization approaches.

import pandas as pd
import numpy as np

# %%
# We can read in our data from our other notebook
ii = pd.read_csv('Users18324DesktopElectronics_5.json')

# %%
ii.head()
ii.drop('Unnamed: 0', axis=1, inplace=True)

# %%
ii.head()
# Out:
#     ProductId  overall      reviewerID  \
# 0  0446697192      4.0  A1A8QJ282YIUQ0
# 1  0446697192      4.0   AX9C10JD538D9
# 2  0446697192      3.0  A2UAM0ITC30078
# 3  0528881469      2.0   A2CPBQ5W4OGBX
# 4  0528881469      5.0  A3H86FCI0QZH7T
#
#                                                title
# 0           Hollywood Is like High School with Money
# 1           Hollywood Is like High School with Money
# 2           Hollywood Is like High School with Money
# 3  Rand McNally 528881469 7-inch Intelliroute TND...
# 4  Rand McNally 528881469 7-inch Intelliroute TND...

# %%
ii.shape
# Out:
# (1049630, 4)

# %% [markdown]
# ### Reducing the dataset

# %% [markdown]
# We can get a breakdown of how many reviews there are for a product. We can reduce our dataset to products that have at least 50 ratings.

# %%
new = pd.DataFrame(ii.groupby('ProductId')['overall'].count())

# %%
new = new[new.overall >= 50]

# %%
new.shape
# Out:
# (3802, 1)

# %%
new = new.sort_values(by='overall',ascending=False)
new
# Out:
#             overall
# ProductId
# B00004ZCJJ     2786
# B00004ZCJI     2656
# B00009KLAE     2642
# B003L1ZYYW     2549
# B0019HL8Q8     2513
# ...             ...
# B004E5J61G       50
# B000WEOWM6       50
# B0000C8VU8       50
# B0000CD0B7       50
# B0055Q7BR4       50
#
# [3802 rows x 1 columns]

# %%
df = ii[ii.ProductId.isin(list(new.index))]

# %%
df.shape
# Out:
# (575349, 4)

# %% [markdown]
# To make the recommender system more relevant, we can also filter the users to those who have at least 15 reviews. This reduces our dataset down to a less computationally taxing size. It will also improve the performance of the recommender system.

# %%
users = pd.DataFrame(ii.groupby('reviewerID')['overall'].count())
users = users[users.overall >= 15]

# %%
df = df[df.reviewerID.isin(users.index)]
df.shape
# Out:
# (16241, 4)

# %%
df1 = df.copy().reset_index(drop=True)

# %%
df1
# Out:
#         ProductId  overall      reviewerID  \
# 0      B00001OWYM      5.0  A25E8V5JMW43RY
# 1      B00001OWYM      5.0  A25E8V5JMW43RY
# 2      B00001OWYM      4.0  A3W4D8XOGLWUN5
# 3      B00001OWYM      4.0  A3W4D8XOGLWUN5
# 4      B00001P4XA      3.0  A2FD5LWT2BXO94
# ...           ...      ...             ...
# 16236  B0091V0A9U      4.0   A54S9CIUV5VNB
# 16237  B0091V0A9U      5.0  A2SRG247VDFTAX
# 16238  B0096T7TQE      1.0  A3IY316DRNF5F2
# 16239  B0096T7TQE      4.0   AHS6PX6H22WW1
# 16240  B0096T7TQE      3.0  A3PD8JD9L4WEII
#
#                                                    title
# 0                          Maxell 290058 Vhs Cleaner Dry
# 1                          Maxell 290058 Vhs Cleaner Dry
# 2                          Maxell 290058 Vhs Cleaner Dry
# 3                          Maxell 290058 Vhs Cleaner Dry
# 4              Koss 'The Plug' In-Ear Headphones (Black)
# ...                                                  ...
# 16236  Pioneer Single DIN In-Dash CD/CD-R/RW, MP3/WMA...
# 16237  Pioneer Single DIN In-Dash CD/CD-R/RW, MP3/WMA...
# 16238  JBL Micro II Ultra-Portable Multimedia Speaker...
# 16239  JBL Micro II Ultra-Portable Multimedia Speaker...
# 16240  JBL Micro II Ultra-Portable Multimedia Speaker...
#
# [16241 rows x 4 columns]

# %% [markdown]
# ### Creating unique ids

# %%
checklist = list(df1.ProductId.unique())

# %%
# Creating unique product integer ids
count = 0
df1['prod_int_id'] = 0
for i in checklist:
    df1['prod_int_id'] = np.where(df1.ProductId == i, count + 1, df1.prod_int_id)
    count += 1

# %%
checklist2 = list(df1.reviewerID.unique())

# %%
# Creating unique user integer ids
count = 0
df1['user_int_id'] = 0
for i in checklist2:
    df1['user_int_id'] = np.where(df1.reviewerID == i, count + 1, df1.user_int_id)
    count += 1

# %%
df1 = df1.drop(['ProductId', 'reviewerID'], axis=1)
df1
# Out:
#        overall                                              title  \
# 0          5.0                      Maxell 290058 Vhs Cleaner Dry
# 1          5.0                      Maxell 290058 Vhs Cleaner Dry
# 2          4.0                      Maxell 290058 Vhs Cleaner Dry
# 3          4.0                      Maxell 290058 Vhs Cleaner Dry
# 4          3.0          Koss 'The Plug' In-Ear Headphones (Black)
# ...        ...                                                ...
# 16236      4.0  Pioneer Single DIN In-Dash CD/CD-R/RW, MP3/WMA...
# 16237      5.0  Pioneer Single DIN In-Dash CD/CD-R/RW, MP3/WMA...
# 16238      1.0  JBL Micro II Ultra-Portable Multimedia Speaker...
# 16239      4.0  JBL Micro II Ultra-Portable Multimedia Speaker...
# 16240      3.0  JBL Micro II Ultra-Portable Multimedia Speaker...
#
#        prod_int_id  user_int_id
# 0                1            1
# 1                1            1
# 2                1            2
# 3                1            2
# 4                2            3
# ...            ...          ...
# 16236         3161          275
# 16237         3161          141
# 16238         3162          444
# 16239         3162         1126
# 16240         3162          572
#
# [16241 rows x 4 columns]

# %% [markdown]
# ### Summary Statistics

# %%
# Avg num ratings per users
print("Avg num ratings per user: {}".format(df.groupby('reviewerID')['overall'].count().mean()))

# Avg num ratings per product
print("Avg num ratings per product: {}".format(df.groupby('ProductId')['overall'].count().mean()))
# Out:
# Avg num ratings per user: 10.02530864197531
# Avg num ratings per product: 5.136306135357369

# %% [markdown]
# ## The Surprise library for recommendations

# %% [markdown]
# We can use the surprise library to compare several approaches to our recommendation system. Here we run cross validation on several different prediction algorithms to identify accuracy and computation times and pick a top performing algorithm.

# %%
from surprise import Reader, Dataset
from surprise.model_selection import train_test_split
from surprise import SVDpp, accuracy
from surprise.model_selection import cross_validate
from surprise import SVD, SlopeOne, NMF, KNNBasic, KNNWithMeans, BaselineOnly, CoClustering

# %%
reader = Reader(rating_scale=(1,5))
data = Dataset.load_from_df(df1[['user_int_id', 'prod_int_id', 'overall']], reader)

# %%
benchmark = []

# Iterate over all algorithms
for algorithm in [SVD(), SlopeOne(), NMF(), KNNBasic(), KNNWithMeans(), BaselineOnly(), CoClustering()]:
    
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=3, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = tmp.append(pd.Series([str(algorithm).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
#               test_rmse  fit_time  test_time
# Algorithm
# SVD            0.898673  0.515327   0.034333
# SlopeOne       0.921118  0.152011   0.034661
# KNNBasic       0.937714  0.053651   0.076683
# BaselineOnly   0.940794  0.013650   0.018668
# KNNWithMeans   0.941776  0.074367   0.070324
# CoClustering   1.016477  0.472633   0.019013
# NMF            1.068980  0.683662   0.023013

# %% [markdown]
# ### Identifying the optimal appraoch: SVD

# %% [markdown]
# SVD seems to have performed best, so we expand on that below. Parameters can always be further optimized through hyperparameter tuning. The SVD uses stochastic gradient descent to minimize the error and so we can adjust parameters such as the learning rate, epochs, and other regularization parameters.

# %%
print('Using ALS')

algo = SVD(n_epochs=5, lr_all = 0.01, reg_all = 0.02, random_state= 42)
cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Using ALS
# {'test_rmse': array([0.92062425, 0.92525717, 0.93906774]),
#  'fit_time': (0.15303277969360352, 0.14400029182434082, 0.1389479637145996),
#  'test_time': (0.025000572204589844, 0.05300021171569824, 0.02499985694885254)}

# %% [markdown]
# ### Train/test split and model building using SVD

# %% [markdown]
# We now create the train/test sets and can make predictions for the ratings using our SVD model.

# %%
trainset, testset = train_test_split(data, test_size=0.25)

algo = SVD(n_epochs=5, lr_all = 0.01, reg_all = 0.02, random_state= 42)

predictions = algo.fit(trainset).test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9309
# 0.9308537018543841

# %%
predictions
# Out:
# [Prediction(uid=168, iid=56, r_ui=4.0, est=4.391373283274269, details={'was_impossible': False}),
#  Prediction(uid=717, iid=564, r_ui=5.0, est=4.43242118627292, details={'was_impossible': False}),
#  Prediction(uid=509, iid=214, r_ui=4.0, est=4.714994559764845, details={'was_impossible': False}),
#  Prediction(uid=684, iid=1684, r_ui=5.0, est=4.181861953014449, details={'was_impossible': False}),
#  Prediction(uid=36, iid=2954, r_ui=4.0, est=4.395872017559877, details={'was_impossible': False}),
#  Prediction(uid=930, iid=1631, r_ui=5.0, est=4.709698870037305, details={'was_impossible': False}),
#  Prediction(uid=246, iid=172, r_ui=4.0, est=4.631199178773854, details={'was_impossible': False}),
#  Prediction(uid=1024, iid=2813, r_ui=5.0, est=4.769432210855679, details={'was_impossible': False}),
#  Prediction(uid=953, iid=1271, r_ui=5.0, est=4.504474960222594, details={'was_impossible': False}),
#  Prediction(uid=1117, iid=521, r_ui=5.0, est=4.4907126999421285, details={'was_impossible': False}),
#  Prediction(uid=1374, iid=2889, r_ui=4.0, est=4.30377896171623, details={'was_impossible': False}),
#  Prediction(uid=303, iid=2245, r_ui=5.0, est=4.492926588393386, details={'was_impossible': False}),
#  Prediction(uid=22, iid=1822, r_ui=4.0, est=4.422881324249771, details={'was_impossible': False}),
#  Prediction(uid=885, iid=1144, r_ui=4.0, est=4.420632883106483, details={'was_impossible': False}),
#  Prediction(uid=983, iid=2809, r_ui=5.0, est=4.704626878096811, details={'was_impossible': False}),
#  Prediction(uid=43, iid=2851, r_ui=5.0, est=4.564271352146268, details={'was_impossible': False}),
#  Prediction(uid=138, iid=683, r_ui=5.0, est=4.420426888287258, details={'was_impossible': False}),
#  Prediction(uid=942, iid=1733, r_ui=5.0, est=4.516434604176329, details={'was_impossible': False}),
#  Prediction(uid=436, iid=2854, r_ui=3.0, est=4.227595306666211, details={'was_impossible': False}),
#  Prediction(uid=242, iid=1886, r_ui=5.0, est=4.510610093787868, details={'was_impossible': False}),
#  Prediction(uid=926, iid=2483, r_ui=5.0, est=4.722047230748428, details={'was_impossible': False}),
#  Prediction(uid=1372, iid=2922, r_ui=5.0, est=4.2171502797043265, details={'was_impossible': False}),
#  Prediction(uid=475, iid=2963, r_ui=5.0, est=4.770664951772811, details={'was_impossible': False}),
#  Prediction(uid=432, iid=1531, r_ui=5.0, est=4.54503947147228, details={'was_impossible': False}),
#  Prediction(uid=813, iid=1537, r_ui=4.0, est=4.681443995798108, details={'was_impossible': False}),
#  Prediction(uid=411, iid=2576, r_ui=5.0, est=4.683158792600347, details={'was_impossible': False}),
#  Prediction(uid=1520, iid=1679, r_ui=5.0, est=4.38856686782493, details={'was_impossible': False}),
#  Prediction(uid=1256, iid=647, r_ui=5.0, est=4.5968366921374795, details={'was_impossible': False}),
#  Prediction(uid=797, iid=2346, r_ui=5.0, est=4.857902775241161, details={'was_impossible': False}),
#  Prediction(uid=113, iid=1538, r_ui=5.0, est=4.176511302677713, details={'was_impossible': False}),
#  Prediction(uid=1000, iid=1613, r_ui=5.0, est=4.665804422821943, details={'was_impossible': False}),
#  Prediction(uid=1466, iid=2363, r_ui=5.0, est=4.460034942581431, details={'was_impossible': False}),
#  Prediction(uid=1070, iid=1209, r_ui=4.0, est=4.359070703277469, details={'was_impossible': False}),
#  Prediction(uid=305, iid=1105, r_ui=4.0, est=4.457683360471565, details={'was_impossible': False}),
#  Prediction(uid=1467, iid=1042, r_ui=4.0, est=4.54697177561403, details={'was_impossible': False}),
#  Prediction(uid=1246, iid=1056, r_ui=5.0, est=4.738403195659967, details={'was_impossible': False}),
#  Prediction(uid=713, iid=776, r_ui=5.0, est=4.759581829261919, details={'was_impossible': False}),
#  Prediction(uid=376, iid=1976, r_ui=5.0, est=4.27750883713287, details={'was_impossible': False}),
#  Prediction(uid=398, iid=909, r_ui=2.0, est=4.552155627408253, details={'was_impossible': False}),
#  Prediction(uid=348, iid=2133, r_ui=5.0, est=4.483445950935301, details={'was_impossible': False}),
#  Prediction(uid=114, iid=1376, r_ui=3.0, est=4.409391023962065, details={'was_impossible': False}),
#  Prediction(uid=570, iid=2348, r_ui=4.0, est=4.120554125126705, details={'was_impossible': False}),
#  Prediction(uid=838, iid=1239, r_ui=5.0, est=4.692001748288575, details={'was_impossible': False}),
#  Prediction(uid=882, iid=1733, r_ui=5.0, est=4.449081110463801, details={'was_impossible': False}),
#  Prediction(uid=1611, iid=2447, r_ui=4.0, est=4.491560656509612, details={'was_impossible': False}),
#  Prediction(uid=1257, iid=1017, r_ui=4.0, est=4.3934975874087145, details={'was_impossible': False}),
#  Prediction(uid=553, iid=1390, r_ui=5.0, est=4.4036969618308675, details={'was_impossible': False}),
#  Prediction(uid=1193, iid=592, r_ui=4.0, est=4.405460823298811, details={'was_impossible': False}),
#  Prediction(uid=267, iid=78, r_ui=5.0, est=4.250399567215335, details={'was_impossible': False}),
#  Prediction(uid=1208, iid=2975, r_ui=3.0, est=3.8711346175656116, details={'was_impossible': False}),
#  Prediction(uid=838, iid=560, r_ui=5.0, est=4.7118705797939215, details={'was_impossible': False}),
#  Prediction(uid=1334, iid=759, r_ui=5.0, est=4.63736376497176, details={'was_impossible': False}),
#  Prediction(uid=151, iid=50, r_ui=5.0, est=4.315122545723455, details={'was_impossible': False}),
#  Prediction(uid=132, iid=43, r_ui=5.0, est=4.5708395389912315, details={'was_impossible': False}),
#  Prediction(uid=983, iid=882, r_ui=5.0, est=4.578653652273173, details={'was_impossible': False}),
#  Prediction(uid=1332, iid=2660, r_ui=4.0, est=4.6015606636339434, details={'was_impossible': False}),
#  Prediction(uid=394, iid=253, r_ui=5.0, est=4.895524116629276, details={'was_impossible': False}),
#  Prediction(uid=1507, iid=2376, r_ui=5.0, est=4.5350651197077, details={'was_impossible': False}),
#  Prediction(uid=1213, iid=2833, r_ui=5.0, est=4.664860669180278, details={'was_impossible': False}),
#  Prediction(uid=29, iid=7, r_ui=3.0, est=4.389638556125536, details={'was_impossible': False}),
#  Prediction(uid=1315, iid=1752, r_ui=5.0, est=4.0848211505685, details={'was_impossible': False}),
#  Prediction(uid=571, iid=198, r_ui=2.0, est=3.849809417110539, details={'was_impossible': False}),
#  Prediction(uid=942, iid=2619, r_ui=5.0, est=4.712654489256772, details={'was_impossible': False}),
#  Prediction(uid=1040, iid=1625, r_ui=5.0, est=4.677929727646106, details={'was_impossible': False}),
#  Prediction(uid=543, iid=2025, r_ui=4.0, est=4.126126512884815, details={'was_impossible': False}),
#  Prediction(uid=1168, iid=2205, r_ui=5.0, est=4.196696304273244, details={'was_impossible': False}),
#  Prediction(uid=983, iid=2254, r_ui=5.0, est=4.602582546650014, details={'was_impossible': False}),
#  Prediction(uid=918, iid=809, r_ui=5.0, est=4.9134544735056656, details={'was_impossible': False}),
#  Prediction(uid=576, iid=1968, r_ui=5.0, est=4.347823440497954, details={'was_impossible': False}),
#  Prediction(uid=674, iid=1472, r_ui=5.0, est=4.294544190294327, details={'was_impossible': False}),
#  Prediction(uid=37, iid=1285, r_ui=4.0, est=4.129588444539997, details={'was_impossible': False}),
#  Prediction(uid=611, iid=216, r_ui=5.0, est=4.562226654870996, details={'was_impossible': False}),
#  Prediction(uid=578, iid=1185, r_ui=5.0, est=4.734679774495391, details={'was_impossible': False}),
#  Prediction(uid=359, iid=1686, r_ui=4.0, est=4.378573170362912, details={'was_impossible': False}),
#  Prediction(uid=346, iid=109, r_ui=1.0, est=4.216365230516555, details={'was_impossible': False}),
#  Prediction(uid=842, iid=2703, r_ui=5.0, est=4.502487425257342, details={'was_impossible': False}),
#  Prediction(uid=408, iid=826, r_ui=5.0, est=4.175598384619123, details={'was_impossible': False}),
#  Prediction(uid=852, iid=2661, r_ui=3.0, est=4.267518689163881, details={'was_impossible': False}),
#  Prediction(uid=456, iid=151, r_ui=5.0, est=4.417924958806576, details={'was_impossible': False}),
#  Prediction(uid=192, iid=375, r_ui=2.0, est=4.565007778584875, details={'was_impossible': False}),
#  Prediction(uid=107, iid=2821, r_ui=4.0, est=4.369185734326004, details={'was_impossible': False}),
#  Prediction(uid=22, iid=776, r_ui=3.0, est=4.571176624342415, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2244, r_ui=4.0, est=4.3631196336817215, details={'was_impossible': False}),
#  Prediction(uid=356, iid=915, r_ui=5.0, est=4.540186710743211, details={'was_impossible': False}),
#  Prediction(uid=308, iid=2819, r_ui=5.0, est=4.856904808883335, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1365, r_ui=4.0, est=4.336664310792529, details={'was_impossible': False}),
#  Prediction(uid=656, iid=1196, r_ui=1.0, est=4.412749352759142, details={'was_impossible': False}),
#  Prediction(uid=914, iid=2619, r_ui=5.0, est=4.684070681546522, details={'was_impossible': False}),
#  Prediction(uid=1162, iid=2619, r_ui=3.0, est=4.536713466309616, details={'was_impossible': False}),
#  Prediction(uid=1087, iid=1133, r_ui=3.0, est=4.698322676968841, details={'was_impossible': False}),
#  Prediction(uid=872, iid=2172, r_ui=4.0, est=4.034211662300645, details={'was_impossible': False}),
#  Prediction(uid=435, iid=2373, r_ui=4.0, est=4.510132450465549, details={'was_impossible': False}),
#  Prediction(uid=897, iid=774, r_ui=5.0, est=4.315679721850109, details={'was_impossible': False}),
#  Prediction(uid=561, iid=1636, r_ui=5.0, est=4.543907526282429, details={'was_impossible': False}),
#  Prediction(uid=1191, iid=2811, r_ui=5.0, est=4.714235369773292, details={'was_impossible': False}),
#  Prediction(uid=257, iid=75, r_ui=5.0, est=4.475937039728635, details={'was_impossible': False}),
#  Prediction(uid=1227, iid=2093, r_ui=3.0, est=4.506099074959845, details={'was_impossible': False}),
#  Prediction(uid=55, iid=2093, r_ui=4.0, est=4.57537156894483, details={'was_impossible': False}),
#  Prediction(uid=453, iid=508, r_ui=5.0, est=4.502133266278355, details={'was_impossible': False}),
#  Prediction(uid=1033, iid=1543, r_ui=5.0, est=4.402321683753048, details={'was_impossible': False}),
#  Prediction(uid=1353, iid=2468, r_ui=5.0, est=4.584974533112063, details={'was_impossible': False}),
#  Prediction(uid=1067, iid=2479, r_ui=5.0, est=4.486528617227214, details={'was_impossible': False}),
#  Prediction(uid=761, iid=872, r_ui=3.0, est=4.362948018155257, details={'was_impossible': False}),
#  Prediction(uid=84, iid=1422, r_ui=5.0, est=4.639532497631133, details={'was_impossible': False}),
#  Prediction(uid=854, iid=490, r_ui=5.0, est=4.580117601514861, details={'was_impossible': False}),
#  Prediction(uid=944, iid=1281, r_ui=5.0, est=4.686257805291327, details={'was_impossible': False}),
#  Prediction(uid=1102, iid=510, r_ui=5.0, est=4.543724647137211, details={'was_impossible': False}),
#  Prediction(uid=752, iid=2210, r_ui=4.0, est=4.640864430259228, details={'was_impossible': False}),
#  Prediction(uid=454, iid=2942, r_ui=5.0, est=4.457065076945796, details={'was_impossible': False}),
#  Prediction(uid=1388, iid=1350, r_ui=5.0, est=4.64126662804554, details={'was_impossible': False}),
#  Prediction(uid=525, iid=1630, r_ui=5.0, est=4.259334345546497, details={'was_impossible': False}),
#  Prediction(uid=1086, iid=1144, r_ui=5.0, est=4.365092206679989, details={'was_impossible': False}),
#  Prediction(uid=431, iid=141, r_ui=5.0, est=4.559017857289359, details={'was_impossible': False}),
#  Prediction(uid=1082, iid=1200, r_ui=5.0, est=4.859955286702799, details={'was_impossible': False}),
#  Prediction(uid=1001, iid=1049, r_ui=4.0, est=4.551748616077551, details={'was_impossible': False}),
#  Prediction(uid=1316, iid=1056, r_ui=1.0, est=3.830006130282061, details={'was_impossible': False}),
#  Prediction(uid=339, iid=2607, r_ui=5.0, est=4.54941631475605, details={'was_impossible': False}),
#  Prediction(uid=969, iid=926, r_ui=4.0, est=4.38219838484676, details={'was_impossible': False}),
#  Prediction(uid=1446, iid=2250, r_ui=4.0, est=4.1288564855683525, details={'was_impossible': False}),
#  Prediction(uid=388, iid=129, r_ui=4.0, est=4.3742594558144035, details={'was_impossible': False}),
#  Prediction(uid=750, iid=2365, r_ui=5.0, est=4.723131890251622, details={'was_impossible': False}),
#  Prediction(uid=886, iid=3002, r_ui=5.0, est=4.249775181335518, details={'was_impossible': False}),
#  Prediction(uid=839, iid=508, r_ui=4.0, est=4.1217943677297555, details={'was_impossible': False}),
#  Prediction(uid=105, iid=844, r_ui=4.0, est=4.204313797214495, details={'was_impossible': False}),
#  Prediction(uid=1325, iid=776, r_ui=5.0, est=4.852527811194472, details={'was_impossible': False}),
#  Prediction(uid=1221, iid=617, r_ui=5.0, est=4.387650405719952, details={'was_impossible': False}),
#  Prediction(uid=582, iid=508, r_ui=5.0, est=4.389342653441746, details={'was_impossible': False}),
#  Prediction(uid=891, iid=2782, r_ui=5.0, est=4.596964483300727, details={'was_impossible': False}),
#  Prediction(uid=662, iid=1508, r_ui=5.0, est=4.126995634045269, details={'was_impossible': False}),
#  Prediction(uid=1423, iid=1390, r_ui=4.0, est=4.004793674399718, details={'was_impossible': False}),
#  Prediction(uid=712, iid=3123, r_ui=5.0, est=4.317579588706332, details={'was_impossible': False}),
#  Prediction(uid=986, iid=1539, r_ui=5.0, est=4.79838062315328, details={'was_impossible': False}),
#  Prediction(uid=1056, iid=485, r_ui=4.0, est=4.704376934535244, details={'was_impossible': False}),
#  Prediction(uid=1077, iid=2896, r_ui=5.0, est=4.595079193514251, details={'was_impossible': False}),
#  Prediction(uid=35, iid=434, r_ui=5.0, est=4.401765351916107, details={'was_impossible': False}),
#  Prediction(uid=492, iid=1622, r_ui=5.0, est=4.620373148018199, details={'was_impossible': False}),
#  Prediction(uid=999, iid=2061, r_ui=5.0, est=4.708775458914933, details={'was_impossible': False}),
#  Prediction(uid=961, iid=1248, r_ui=4.0, est=4.241847058540907, details={'was_impossible': False}),
#  Prediction(uid=41, iid=185, r_ui=5.0, est=4.457524187583399, details={'was_impossible': False}),
#  Prediction(uid=581, iid=2814, r_ui=5.0, est=4.654753441750516, details={'was_impossible': False}),
#  Prediction(uid=1325, iid=2592, r_ui=5.0, est=4.674232864155465, details={'was_impossible': False}),
#  Prediction(uid=324, iid=1705, r_ui=4.0, est=3.9200750218444895, details={'was_impossible': False}),
#  Prediction(uid=1404, iid=2595, r_ui=5.0, est=3.7082465030601908, details={'was_impossible': False}),
#  Prediction(uid=129, iid=2039, r_ui=5.0, est=4.672987949623572, details={'was_impossible': False}),
#  Prediction(uid=620, iid=224, r_ui=4.0, est=4.389359428423232, details={'was_impossible': False}),
#  Prediction(uid=1111, iid=518, r_ui=4.0, est=4.035025222828209, details={'was_impossible': False}),
#  Prediction(uid=771, iid=2757, r_ui=5.0, est=4.651675652379772, details={'was_impossible': False}),
#  Prediction(uid=1166, iid=1539, r_ui=5.0, est=4.799509751973565, details={'was_impossible': False}),
#  Prediction(uid=764, iid=2706, r_ui=5.0, est=4.705621973960009, details={'was_impossible': False}),
#  Prediction(uid=54, iid=1975, r_ui=5.0, est=4.355052915736373, details={'was_impossible': False}),
#  Prediction(uid=1091, iid=1523, r_ui=5.0, est=4.44531333088222, details={'was_impossible': False}),
#  Prediction(uid=1383, iid=2484, r_ui=5.0, est=4.029694073773058, details={'was_impossible': False}),
#  Prediction(uid=188, iid=632, r_ui=5.0, est=4.479095270670397, details={'was_impossible': False}),
#  Prediction(uid=240, iid=836, r_ui=5.0, est=4.202645323190617, details={'was_impossible': False}),
#  Prediction(uid=125, iid=1733, r_ui=5.0, est=4.4015186123620715, details={'was_impossible': False}),
#  Prediction(uid=377, iid=170, r_ui=4.0, est=4.276395376111271, details={'was_impossible': False}),
#  Prediction(uid=466, iid=638, r_ui=5.0, est=4.21038677317567, details={'was_impossible': False}),
#  Prediction(uid=1517, iid=1213, r_ui=3.0, est=4.389197566231686, details={'was_impossible': False}),
#  Prediction(uid=1098, iid=2089, r_ui=5.0, est=4.593925253281493, details={'was_impossible': False}),
#  Prediction(uid=1263, iid=2711, r_ui=4.0, est=4.348361023194142, details={'was_impossible': False}),
#  Prediction(uid=99, iid=1568, r_ui=5.0, est=4.716276573649248, details={'was_impossible': False}),
#  Prediction(uid=435, iid=1361, r_ui=5.0, est=4.33093696576952, details={'was_impossible': False}),
#  Prediction(uid=509, iid=173, r_ui=5.0, est=4.032384851688391, details={'was_impossible': False}),
#  Prediction(uid=564, iid=2480, r_ui=5.0, est=4.69409728978005, details={'was_impossible': False}),
#  Prediction(uid=749, iid=2339, r_ui=5.0, est=4.626456017016746, details={'was_impossible': False}),
#  Prediction(uid=200, iid=1554, r_ui=4.0, est=4.419423026179845, details={'was_impossible': False}),
#  Prediction(uid=1012, iid=1027, r_ui=5.0, est=4.37893142594435, details={'was_impossible': False}),
#  Prediction(uid=519, iid=2649, r_ui=5.0, est=4.6055623501562435, details={'was_impossible': False}),
#  Prediction(uid=94, iid=29, r_ui=5.0, est=4.780927367087791, details={'was_impossible': False}),
#  Prediction(uid=631, iid=1780, r_ui=4.0, est=4.384239062498675, details={'was_impossible': False}),
#  Prediction(uid=92, iid=322, r_ui=5.0, est=4.37723632596042, details={'was_impossible': False}),
#  Prediction(uid=775, iid=1376, r_ui=3.0, est=4.525063582141653, details={'was_impossible': False}),
#  Prediction(uid=618, iid=963, r_ui=5.0, est=4.640825273679638, details={'was_impossible': False}),
#  Prediction(uid=502, iid=167, r_ui=5.0, est=3.8400337027899867, details={'was_impossible': False}),
#  Prediction(uid=1546, iid=1365, r_ui=1.0, est=4.686405905688981, details={'was_impossible': False}),
#  Prediction(uid=560, iid=193, r_ui=5.0, est=4.842315654463819, details={'was_impossible': False}),
#  Prediction(uid=937, iid=732, r_ui=5.0, est=4.67896272644487, details={'was_impossible': False}),
#  Prediction(uid=916, iid=2052, r_ui=5.0, est=4.959279515260259, details={'was_impossible': False}),
#  Prediction(uid=390, iid=2491, r_ui=5.0, est=4.730766722860797, details={'was_impossible': False}),
#  Prediction(uid=1539, iid=1948, r_ui=5.0, est=4.20820185179974, details={'was_impossible': False}),
#  Prediction(uid=798, iid=2690, r_ui=1.0, est=4.03078230561142, details={'was_impossible': False}),
#  Prediction(uid=1138, iid=2231, r_ui=5.0, est=4.579104889382767, details={'was_impossible': False}),
#  Prediction(uid=1416, iid=1018, r_ui=5.0, est=4.604640365409691, details={'was_impossible': False}),
#  Prediction(uid=206, iid=277, r_ui=5.0, est=4.516873540581912, details={'was_impossible': False}),
#  Prediction(uid=66, iid=16, r_ui=4.0, est=4.450745172578052, details={'was_impossible': False}),
#  Prediction(uid=580, iid=1346, r_ui=4.0, est=4.901048218035899, details={'was_impossible': False}),
#  Prediction(uid=1141, iid=1030, r_ui=5.0, est=4.733515182217892, details={'was_impossible': False}),
#  Prediction(uid=586, iid=961, r_ui=5.0, est=4.075813144487174, details={'was_impossible': False}),
#  Prediction(uid=271, iid=2587, r_ui=4.0, est=4.446552292658768, details={'was_impossible': False}),
#  Prediction(uid=1072, iid=1018, r_ui=5.0, est=4.720903128632009, details={'was_impossible': False}),
#  Prediction(uid=984, iid=874, r_ui=5.0, est=4.5905218029096, details={'was_impossible': False}),
#  Prediction(uid=302, iid=2077, r_ui=5.0, est=4.8696969674375055, details={'was_impossible': False}),
#  Prediction(uid=974, iid=420, r_ui=5.0, est=4.579908062673871, details={'was_impossible': False}),
#  Prediction(uid=1258, iid=2466, r_ui=5.0, est=4.771512930104627, details={'was_impossible': False}),
#  Prediction(uid=1025, iid=1029, r_ui=5.0, est=4.468857610619831, details={'was_impossible': False}),
#  Prediction(uid=355, iid=464, r_ui=4.0, est=4.818026249443986, details={'was_impossible': False}),
#  Prediction(uid=721, iid=1985, r_ui=4.0, est=4.51708799059168, details={'was_impossible': False}),
#  Prediction(uid=348, iid=1613, r_ui=4.0, est=4.277629668118813, details={'was_impossible': False}),
#  Prediction(uid=434, iid=2806, r_ui=5.0, est=4.526679753491549, details={'was_impossible': False}),
#  Prediction(uid=881, iid=353, r_ui=5.0, est=4.241257069713474, details={'was_impossible': False}),
#  Prediction(uid=302, iid=653, r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid=108, iid=779, r_ui=5.0, est=4.3983359539260904, details={'was_impossible': False}),
#  Prediction(uid=1333, iid=961, r_ui=5.0, est=4.273709790483527, details={'was_impossible': False}),
#  Prediction(uid=1241, iid=638, r_ui=5.0, est=4.271924459396562, details={'was_impossible': False}),
#  Prediction(uid=146, iid=2059, r_ui=4.0, est=4.457071111810339, details={'was_impossible': False}),
#  Prediction(uid=989, iid=1838, r_ui=4.0, est=4.676323219907628, details={'was_impossible': False}),
#  Prediction(uid=882, iid=356, r_ui=5.0, est=4.582371283364003, details={'was_impossible': False}),
#  Prediction(uid=539, iid=2059, r_ui=5.0, est=4.591489698757577, details={'was_impossible': False}),
#  Prediction(uid=1275, iid=1826, r_ui=5.0, est=4.506426367887499, details={'was_impossible': False}),
#  Prediction(uid=316, iid=210, r_ui=4.0, est=4.35740660423575, details={'was_impossible': False}),
#  Prediction(uid=256, iid=2337, r_ui=1.0, est=4.008927525619398, details={'was_impossible': False}),
#  Prediction(uid=992, iid=1594, r_ui=5.0, est=4.41114192394294, details={'was_impossible': False}),
#  Prediction(uid=1354, iid=2043, r_ui=5.0, est=4.283739195794441, details={'was_impossible': False}),
#  Prediction(uid=302, iid=1325, r_ui=5.0, est=4.665983439860918, details={'was_impossible': False}),
#  Prediction(uid=1360, iid=2770, r_ui=1.0, est=4.442359092241122, details={'was_impossible': False}),
#  Prediction(uid=718, iid=2769, r_ui=3.0, est=4.432733701544922, details={'was_impossible': False}),
#  Prediction(uid=140, iid=1908, r_ui=4.0, est=4.379638392426063, details={'was_impossible': False}),
#  Prediction(uid=445, iid=1056, r_ui=5.0, est=4.7759972065792775, details={'was_impossible': False}),
#  Prediction(uid=733, iid=552, r_ui=4.0, est=4.324328492445732, details={'was_impossible': False}),
#  Prediction(uid=1441, iid=2555, r_ui=5.0, est=4.353873727912328, details={'was_impossible': False}),
#  Prediction(uid=1062, iid=1522, r_ui=5.0, est=4.554455045611211, details={'was_impossible': False}),
#  Prediction(uid=354, iid=576, r_ui=5.0, est=4.83023781968793, details={'was_impossible': False}),
#  Prediction(uid=625, iid=1522, r_ui=2.0, est=3.5296259692429595, details={'was_impossible': False}),
#  Prediction(uid=857, iid=801, r_ui=3.0, est=4.263244501606466, details={'was_impossible': False}),
#  Prediction(uid=502, iid=677, r_ui=5.0, est=3.9850681282592344, details={'was_impossible': False}),
#  Prediction(uid=864, iid=511, r_ui=5.0, est=4.6141266460699075, details={'was_impossible': False}),
#  Prediction(uid=1208, iid=2466, r_ui=2.0, est=4.05346898505787, details={'was_impossible': False}),
#  Prediction(uid=1250, iid=644, r_ui=4.0, est=4.326577681848604, details={'was_impossible': False}),
#  Prediction(uid=106, iid=33, r_ui=4.0, est=4.665087728145734, details={'was_impossible': False}),
#  Prediction(uid=277, iid=1009, r_ui=5.0, est=4.950428253906926, details={'was_impossible': False}),
#  Prediction(uid=993, iid=437, r_ui=5.0, est=4.591549050702211, details={'was_impossible': False}),
#  Prediction(uid=189, iid=608, r_ui=5.0, est=4.465601159771884, details={'was_impossible': False}),
#  Prediction(uid=741, iid=830, r_ui=5.0, est=4.693083960952527, details={'was_impossible': False}),
#  Prediction(uid=888, iid=1058, r_ui=5.0, est=4.752200155137453, details={'was_impossible': False}),
#  Prediction(uid=424, iid=198, r_ui=5.0, est=2.748649559723558, details={'was_impossible': False}),
#  Prediction(uid=1327, iid=750, r_ui=5.0, est=4.286257992064619, details={'was_impossible': False}),
#  Prediction(uid=676, iid=1288, r_ui=5.0, est=4.61147636448493, details={'was_impossible': False}),
#  Prediction(uid=185, iid=2530, r_ui=4.0, est=3.91116384116296, details={'was_impossible': False}),
#  Prediction(uid=116, iid=1736, r_ui=5.0, est=4.556200136943379, details={'was_impossible': False}),
#  Prediction(uid=1038, iid=2481, r_ui=1.0, est=4.198977667786094, details={'was_impossible': False}),
#  Prediction(uid=106, iid=375, r_ui=5.0, est=4.580027313493936, details={'was_impossible': False}),
#  Prediction(uid=1156, iid=1227, r_ui=5.0, est=4.322225638269467, details={'was_impossible': False}),
#  Prediction(uid=1445, iid=2069, r_ui=4.0, est=4.502052085123995, details={'was_impossible': False}),
#  Prediction(uid=535, iid=2819, r_ui=5.0, est=4.839765686712987, details={'was_impossible': False}),
#  Prediction(uid=1203, iid=1878, r_ui=5.0, est=4.526577551751149, details={'was_impossible': False}),
#  Prediction(uid=1247, iid=1499, r_ui=4.0, est=4.430928936269681, details={'was_impossible': False}),
#  Prediction(uid=837, iid=2168, r_ui=5.0, est=4.564117670095849, details={'was_impossible': False}),
#  Prediction(uid=793, iid=1170, r_ui=5.0, est=4.4903328936761815, details={'was_impossible': False}),
#  Prediction(uid=1211, iid=1415, r_ui=4.0, est=4.13085314738382, details={'was_impossible': False}),
#  Prediction(uid=1600, iid=2067, r_ui=5.0, est=4.548152618982069, details={'was_impossible': False}),
#  Prediction(uid=521, iid=579, r_ui=5.0, est=4.616166413556668, details={'was_impossible': False}),
#  Prediction(uid=151, iid=50, r_ui=5.0, est=4.315122545723455, details={'was_impossible': False}),
#  Prediction(uid=108, iid=565, r_ui=5.0, est=4.562468651239844, details={'was_impossible': False}),
#  Prediction(uid=112, iid=2339, r_ui=5.0, est=4.90239530174035, details={'was_impossible': False}),
#  Prediction(uid=48, iid=13, r_ui=5.0, est=4.284384626331149, details={'was_impossible': False}),
#  Prediction(uid=164, iid=3068, r_ui=5.0, est=4.992635715087042, details={'was_impossible': False}),
#  Prediction(uid=39, iid=632, r_ui=5.0, est=4.11681666973916, details={'was_impossible': False}),
#  Prediction(uid=471, iid=1848, r_ui=5.0, est=4.550474556997966, details={'was_impossible': False}),
#  Prediction(uid=137, iid=412, r_ui=4.0, est=4.379012000108098, details={'was_impossible': False}),
#  Prediction(uid=858, iid=508, r_ui=2.0, est=3.4717166155559775, details={'was_impossible': False}),
#  Prediction(uid=1131, iid=593, r_ui=5.0, est=4.061997891629539, details={'was_impossible': False}),
#  Prediction(uid=426, iid=425, r_ui=1.0, est=4.202578804814244, details={'was_impossible': False}),
#  Prediction(uid=55, iid=2328, r_ui=4.0, est=4.600290090992125, details={'was_impossible': False}),
#  Prediction(uid=419, iid=761, r_ui=4.0, est=4.675012334314134, details={'was_impossible': False}),
#  Prediction(uid=1501, iid=3076, r_ui=5.0, est=4.471241980865583, details={'was_impossible': False}),
#  Prediction(uid=1509, iid=2928, r_ui=4.0, est=4.705411045790867, details={'was_impossible': False}),
#  Prediction(uid=488, iid=2641, r_ui=5.0, est=4.2795414861677274, details={'was_impossible': False}),
#  Prediction(uid=216, iid=1051, r_ui=2.0, est=3.7807964461638304, details={'was_impossible': False}),
#  Prediction(uid=626, iid=1737, r_ui=2.0, est=4.428905322370691, details={'was_impossible': False}),
#  Prediction(uid=163, iid=274, r_ui=1.0, est=3.710236021966715, details={'was_impossible': False}),
#  Prediction(uid=870, iid=1134, r_ui=5.0, est=4.412483053845096, details={'was_impossible': False}),
#  Prediction(uid=53, iid=14, r_ui=4.0, est=4.258223596887707, details={'was_impossible': False}),
#  Prediction(uid=312, iid=447, r_ui=5.0, est=4.426282884912515, details={'was_impossible': False}),
#  Prediction(uid=1468, iid=1837, r_ui=2.0, est=4.279177040578692, details={'was_impossible': False}),
#  Prediction(uid=807, iid=1582, r_ui=5.0, est=4.617485002230461, details={'was_impossible': False}),
#  Prediction(uid=399, iid=274, r_ui=2.0, est=3.7808207513009497, details={'was_impossible': False}),
#  Prediction(uid=1490, iid=1352, r_ui=5.0, est=4.32742411887532, details={'was_impossible': False}),
#  Prediction(uid=813, iid=1537, r_ui=4.0, est=4.681443995798108, details={'was_impossible': False}),
#  Prediction(uid=694, iid=1864, r_ui=5.0, est=4.2224600241741035, details={'was_impossible': False}),
#  Prediction(uid=89, iid=2829, r_ui=5.0, est=4.543767223136753, details={'was_impossible': False}),
#  Prediction(uid=749, iid=2137, r_ui=5.0, est=4.510477261704019, details={'was_impossible': False}),
#  Prediction(uid=1164, iid=1792, r_ui=5.0, est=4.867770645265246, details={'was_impossible': False}),
#  Prediction(uid=399, iid=489, r_ui=5.0, est=4.369861615807065, details={'was_impossible': False}),
#  Prediction(uid=35, iid=1275, r_ui=4.0, est=4.426298914150976, details={'was_impossible': False}),
#  Prediction(uid=1020, iid=1244, r_ui=5.0, est=4.616484573283834, details={'was_impossible': False}),
#  Prediction(uid=484, iid=2779, r_ui=5.0, est=4.142290924384267, details={'was_impossible': False}),
#  Prediction(uid=1595, iid=2065, r_ui=5.0, est=4.571909634371813, details={'was_impossible': False}),
#  Prediction(uid=958, iid=1299, r_ui=4.0, est=4.582907610795808, details={'was_impossible': False}),
#  Prediction(uid=65, iid=2890, r_ui=5.0, est=4.401708230943925, details={'was_impossible': False}),
#  Prediction(uid=685, iid=1257, r_ui=3.0, est=4.43947067446486, details={'was_impossible': False}),
#  Prediction(uid=458, iid=1482, r_ui=3.0, est=4.976073936941358, details={'was_impossible': False}),
#  Prediction(uid=1158, iid=653, r_ui=5.0, est=4.93695001178175, details={'was_impossible': False}),
#  Prediction(uid=999, iid=1585, r_ui=5.0, est=4.671509874964938, details={'was_impossible': False}),
#  Prediction(uid=947, iid=404, r_ui=5.0, est=4.02465452909113, details={'was_impossible': False}),
#  Prediction(uid=1280, iid=1707, r_ui=5.0, est=4.134737531156362, details={'was_impossible': False}),
#  Prediction(uid=514, iid=2261, r_ui=5.0, est=3.766851434792382, details={'was_impossible': False}),
#  Prediction(uid=54, iid=986, r_ui=5.0, est=4.373925847018806, details={'was_impossible': False}),
#  Prediction(uid=412, iid=1494, r_ui=5.0, est=4.469200577947107, details={'was_impossible': False}),
#  Prediction(uid=1427, iid=1071, r_ui=5.0, est=4.122968127038237, details={'was_impossible': False}),
#  Prediction(uid=1324, iid=747, r_ui=4.0, est=4.555657525875762, details={'was_impossible': False}),
#  Prediction(uid=1325, iid=1568, r_ui=5.0, est=4.607985133864799, details={'was_impossible': False}),
#  Prediction(uid=632, iid=1065, r_ui=5.0, est=4.268028013905061, details={'was_impossible': False}),
#  Prediction(uid=1438, iid=2110, r_ui=3.0, est=4.383221987520176, details={'was_impossible': False}),
#  Prediction(uid=1127, iid=1011, r_ui=5.0, est=4.845373308544046, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2052, r_ui=5.0, est=4.662201582158368, details={'was_impossible': False}),
#  Prediction(uid=869, iid=2625, r_ui=5.0, est=4.656600784530463, details={'was_impossible': False}),
#  Prediction(uid=532, iid=1062, r_ui=2.0, est=3.851334729488458, details={'was_impossible': False}),
#  Prediction(uid=330, iid=1902, r_ui=5.0, est=4.420678364766539, details={'was_impossible': False}),
#  Prediction(uid=1398, iid=1196, r_ui=5.0, est=4.498788469476715, details={'was_impossible': False}),
#  Prediction(uid=1262, iid=1805, r_ui=3.0, est=3.6228494075413953, details={'was_impossible': False}),
#  Prediction(uid=193, iid=63, r_ui=5.0, est=4.446320078816739, details={'was_impossible': False}),
#  Prediction(uid=1349, iid=1573, r_ui=5.0, est=4.366000302531457, details={'was_impossible': False}),
#  Prediction(uid=327, iid=103, r_ui=5.0, est=4.269536471711186, details={'was_impossible': False}),
#  Prediction(uid=748, iid=795, r_ui=5.0, est=4.790001278435685, details={'was_impossible': False}),
#  Prediction(uid=16, iid=3099, r_ui=5.0, est=4.638544034480465, details={'was_impossible': False}),
#  Prediction(uid=1340, iid=820, r_ui=5.0, est=4.713163714870162, details={'was_impossible': False}),
#  Prediction(uid=258, iid=2865, r_ui=5.0, est=4.9442602322419775, details={'was_impossible': False}),
#  Prediction(uid=810, iid=314, r_ui=4.0, est=4.431943669442653, details={'was_impossible': False}),
#  Prediction(uid=545, iid=1516, r_ui=5.0, est=4.752648367886043, details={'was_impossible': False}),
#  Prediction(uid=1466, iid=1955, r_ui=5.0, est=4.46596228749311, details={'was_impossible': False}),
#  Prediction(uid=275, iid=1932, r_ui=4.0, est=4.6281647637516485, details={'was_impossible': False}),
#  Prediction(uid=1402, iid=2172, r_ui=5.0, est=4.885003117991649, details={'was_impossible': False}),
#  Prediction(uid=51, iid=968, r_ui=5.0, est=4.541051101165329, details={'was_impossible': False}),
#  Prediction(uid=713, iid=474, r_ui=5.0, est=4.427599013824684, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1544, r_ui=5.0, est=4.621813180528801, details={'was_impossible': False}),
#  Prediction(uid=1270, iid=1657, r_ui=5.0, est=4.471450995849089, details={'was_impossible': False}),
#  Prediction(uid=432, iid=141, r_ui=5.0, est=4.361453070499665, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1878, r_ui=5.0, est=4.815225117561708, details={'was_impossible': False}),
#  Prediction(uid=724, iid=1864, r_ui=3.0, est=4.5979733193745105, details={'was_impossible': False}),
#  Prediction(uid=838, iid=2635, r_ui=5.0, est=4.875040831937868, details={'was_impossible': False}),
#  Prediction(uid=960, iid=1348, r_ui=5.0, est=4.196413315657573, details={'was_impossible': False}),
#  Prediction(uid=644, iid=2629, r_ui=5.0, est=4.7362636689057975, details={'was_impossible': False}),
#  Prediction(uid=759, iid=1607, r_ui=5.0, est=4.291571039251973, details={'was_impossible': False}),
#  Prediction(uid=259, iid=2069, r_ui=5.0, est=4.927009528517464, details={'was_impossible': False}),
#  Prediction(uid=908, iid=1713, r_ui=3.0, est=3.8916044661237708, details={'was_impossible': False}),
#  Prediction(uid=1338, iid=3055, r_ui=2.0, est=4.546402750345029, details={'was_impossible': False}),
#  Prediction(uid=1288, iid=2184, r_ui=4.0, est=4.590887089181491, details={'was_impossible': False}),
#  Prediction(uid=1027, iid=2052, r_ui=5.0, est=4.794083946197881, details={'was_impossible': False}),
#  Prediction(uid=295, iid=90, r_ui=4.0, est=4.4264432136441, details={'was_impossible': False}),
#  Prediction(uid=1043, iid=2579, r_ui=3.0, est=4.45818662333046, details={'was_impossible': False}),
#  Prediction(uid=32, iid=2937, r_ui=5.0, est=4.7197743375847585, details={'was_impossible': False}),
#  Prediction(uid=591, iid=551, r_ui=5.0, est=4.806154453386833, details={'was_impossible': False}),
#  Prediction(uid=73, iid=1458, r_ui=5.0, est=4.934651662549346, details={'was_impossible': False}),
#  Prediction(uid=1398, iid=1277, r_ui=5.0, est=4.305461384963929, details={'was_impossible': False}),
#  Prediction(uid=1547, iid=2572, r_ui=5.0, est=4.339708384254201, details={'was_impossible': False}),
#  Prediction(uid=1145, iid=1133, r_ui=4.0, est=4.503204211836968, details={'was_impossible': False}),
#  Prediction(uid=891, iid=1030, r_ui=5.0, est=4.89905949610334, details={'was_impossible': False}),
#  Prediction(uid=1307, iid=1582, r_ui=5.0, est=4.058703072728658, details={'was_impossible': False}),
#  Prediction(uid=605, iid=451, r_ui=3.0, est=4.143254240626775, details={'was_impossible': False}),
#  Prediction(uid=326, iid=103, r_ui=5.0, est=3.8713243356672944, details={'was_impossible': False}),
#  Prediction(uid=762, iid=908, r_ui=5.0, est=4.142997418131023, details={'was_impossible': False}),
#  Prediction(uid=405, iid=2692, r_ui=5.0, est=4.704356760166993, details={'was_impossible': False}),
#  Prediction(uid=240, iid=418, r_ui=5.0, est=4.2625902268907065, details={'was_impossible': False}),
#  Prediction(uid=911, iid=1555, r_ui=5.0, est=4.14367126418823, details={'was_impossible': False}),
#  Prediction(uid=1472, iid=2086, r_ui=3.0, est=4.1888556627285185, details={'was_impossible': False}),
#  Prediction(uid=1093, iid=1151, r_ui=5.0, est=4.031487578600379, details={'was_impossible': False}),
#  Prediction(uid=1359, iid=2609, r_ui=5.0, est=4.620506158649087, details={'was_impossible': False}),
#  Prediction(uid=1399, iid=1047, r_ui=4.0, est=4.779921279434862, details={'was_impossible': False}),
#  Prediction(uid=719, iid=2823, r_ui=4.0, est=4.30523624743947, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1716, r_ui=4.0, est=4.244220544647048, details={'was_impossible': False}),
#  Prediction(uid=466, iid=1774, r_ui=5.0, est=4.244523405591116, details={'was_impossible': False}),
#  Prediction(uid=1172, iid=576, r_ui=5.0, est=4.49272127895851, details={'was_impossible': False}),
#  Prediction(uid=1438, iid=1808, r_ui=4.0, est=4.5972241050299765, details={'was_impossible': False}),
#  Prediction(uid=1578, iid=2950, r_ui=5.0, est=4.499404683801911, details={'was_impossible': False}),
#  Prediction(uid=323, iid=2921, r_ui=2.0, est=4.3079772882191625, details={'was_impossible': False}),
#  Prediction(uid=400, iid=2430, r_ui=5.0, est=4.485674916906496, details={'was_impossible': False}),
#  Prediction(uid=729, iid=1951, r_ui=5.0, est=4.5301838300317465, details={'was_impossible': False}),
#  Prediction(uid=296, iid=460, r_ui=4.0, est=4.514254117374149, details={'was_impossible': False}),
#  Prediction(uid=1465, iid=1039, r_ui=5.0, est=4.501254883859528, details={'was_impossible': False}),
#  Prediction(uid=889, iid=2277, r_ui=3.0, est=4.219487076831693, details={'was_impossible': False}),
#  Prediction(uid=1422, iid=2618, r_ui=5.0, est=4.85202806639699, details={'was_impossible': False}),
#  Prediction(uid=1286, iid=2604, r_ui=5.0, est=4.531933193152157, details={'was_impossible': False}),
#  Prediction(uid=954, iid=1566, r_ui=4.0, est=3.7467891368588355, details={'was_impossible': False}),
#  Prediction(uid=1051, iid=1558, r_ui=5.0, est=4.871367414921334, details={'was_impossible': False}),
#  Prediction(uid=1183, iid=1251, r_ui=5.0, est=4.439185522246886, details={'was_impossible': False}),
#  Prediction(uid=675, iid=1091, r_ui=5.0, est=4.3234063853980205, details={'was_impossible': False}),
#  Prediction(uid=424, iid=1708, r_ui=1.0, est=3.263695286759617, details={'was_impossible': False}),
#  Prediction(uid=1395, iid=1077, r_ui=4.0, est=4.240582933548245, details={'was_impossible': False}),
#  Prediction(uid=1354, iid=1346, r_ui=4.0, est=4.689328606643877, details={'was_impossible': False}),
#  Prediction(uid=1017, iid=625, r_ui=5.0, est=4.423647293990507, details={'was_impossible': False}),
#  Prediction(uid=133, iid=2398, r_ui=3.0, est=4.432959275948535, details={'was_impossible': False}),
#  Prediction(uid=1507, iid=1844, r_ui=4.0, est=4.5350651197077, details={'was_impossible': False}),
#  Prediction(uid=622, iid=224, r_ui=5.0, est=4.299529555820318, details={'was_impossible': False}),
#  Prediction(uid=1265, iid=1612, r_ui=5.0, est=4.463145552554613, details={'was_impossible': False}),
#  Prediction(uid=682, iid=458, r_ui=5.0, est=4.806754899190161, details={'was_impossible': False}),
#  Prediction(uid=1105, iid=2466, r_ui=5.0, est=4.651279846742351, details={'was_impossible': False}),
#  Prediction(uid=543, iid=878, r_ui=1.0, est=4.408480866821925, details={'was_impossible': False}),
#  Prediction(uid=1033, iid=1525, r_ui=3.0, est=4.151003963633934, details={'was_impossible': False}),
#  Prediction(uid=441, iid=1666, r_ui=5.0, est=4.53603706010428, details={'was_impossible': False}),
#  Prediction(uid=573, iid=1632, r_ui=5.0, est=4.294673600018848, details={'was_impossible': False}),
#  Prediction(uid=297, iid=625, r_ui=4.0, est=4.417446116257318, details={'was_impossible': False}),
#  Prediction(uid=1513, iid=1201, r_ui=4.0, est=4.34386855415378, details={'was_impossible': False}),
#  Prediction(uid=1139, iid=1271, r_ui=5.0, est=4.311941536099178, details={'was_impossible': False}),
#  Prediction(uid=927, iid=1895, r_ui=1.0, est=3.5536857437704215, details={'was_impossible': False}),
#  Prediction(uid=1248, iid=644, r_ui=3.0, est=4.226061217881053, details={'was_impossible': False}),
#  Prediction(uid=1398, iid=2168, r_ui=5.0, est=4.507055432931865, details={'was_impossible': False}),
#  Prediction(uid=560, iid=2503, r_ui=5.0, est=4.482914398322757, details={'was_impossible': False}),
#  Prediction(uid=65, iid=548, r_ui=5.0, est=4.69214636490929, details={'was_impossible': False}),
#  Prediction(uid=408, iid=613, r_ui=4.0, est=4.4539903353292924, details={'was_impossible': False}),
#  Prediction(uid=447, iid=1686, r_ui=5.0, est=4.325197158200343, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2944, r_ui=5.0, est=4.3703479504475435, details={'was_impossible': False}),
#  Prediction(uid=1318, iid=2948, r_ui=4.0, est=4.035725194990593, details={'was_impossible': False}),
#  Prediction(uid=91, iid=1865, r_ui=5.0, est=4.247669575710607, details={'was_impossible': False}),
#  Prediction(uid=897, iid=774, r_ui=5.0, est=4.315679721850109, details={'was_impossible': False}),
#  Prediction(uid=819, iid=2260, r_ui=5.0, est=4.50246723340592, details={'was_impossible': False}),
#  Prediction(uid=80, iid=638, r_ui=5.0, est=4.199530533778653, details={'was_impossible': False}),
#  Prediction(uid=1025, iid=2220, r_ui=5.0, est=4.603508158881184, details={'was_impossible': False}),
#  Prediction(uid=666, iid=637, r_ui=4.0, est=4.507557299045924, details={'was_impossible': False}),
#  Prediction(uid=1035, iid=2274, r_ui=1.0, est=4.466848325261655, details={'was_impossible': False}),
#  Prediction(uid=1024, iid=3023, r_ui=5.0, est=4.347651454394251, details={'was_impossible': False}),
#  Prediction(uid=687, iid=1271, r_ui=5.0, est=4.144624820329177, details={'was_impossible': False}),
#  Prediction(uid=363, iid=175, r_ui=4.0, est=4.402682037636501, details={'was_impossible': False}),
#  Prediction(uid=527, iid=178, r_ui=4.0, est=4.376686606432714, details={'was_impossible': False}),
#  Prediction(uid=771, iid=2911, r_ui=4.0, est=4.42523757746036, details={'was_impossible': False}),
#  Prediction(uid=890, iid=2819, r_ui=5.0, est=4.776541560462303, details={'was_impossible': False}),
#  Prediction(uid=1223, iid=3148, r_ui=4.0, est=4.4349112494633856, details={'was_impossible': False}),
#  Prediction(uid=69, iid=849, r_ui=4.0, est=4.647283630340433, details={'was_impossible': False}),
#  Prediction(uid=1599, iid=2044, r_ui=2.0, est=3.8962819649059135, details={'was_impossible': False}),
#  Prediction(uid=755, iid=797, r_ui=2.0, est=4.609871342868863, details={'was_impossible': False}),
#  Prediction(uid=826, iid=2745, r_ui=5.0, est=4.562155611660031, details={'was_impossible': False}),
#  Prediction(uid=395, iid=2142, r_ui=3.0, est=4.472335234587507, details={'was_impossible': False}),
#  Prediction(uid=1412, iid=2844, r_ui=4.0, est=4.101372564061894, details={'was_impossible': False}),
#  Prediction(uid=976, iid=1487, r_ui=4.0, est=4.32711750646203, details={'was_impossible': False}),
#  Prediction(uid=785, iid=299, r_ui=4.0, est=4.164846355133207, details={'was_impossible': False}),
#  Prediction(uid=454, iid=527, r_ui=4.0, est=4.43341329456134, details={'was_impossible': False}),
#  Prediction(uid=825, iid=2595, r_ui=1.0, est=2.9665561756191217, details={'was_impossible': False}),
#  Prediction(uid=322, iid=1566, r_ui=5.0, est=3.8922177476227477, details={'was_impossible': False}),
#  Prediction(uid=1495, iid=1110, r_ui=5.0, est=4.554299772619678, details={'was_impossible': False}),
#  Prediction(uid=900, iid=576, r_ui=5.0, est=4.71082165160021, details={'was_impossible': False}),
#  Prediction(uid=483, iid=1352, r_ui=5.0, est=4.3467737951843, details={'was_impossible': False}),
#  Prediction(uid=839, iid=2343, r_ui=5.0, est=4.56530869521318, details={'was_impossible': False}),
#  Prediction(uid=1213, iid=1131, r_ui=4.0, est=4.473103074834668, details={'was_impossible': False}),
#  Prediction(uid=1135, iid=2198, r_ui=5.0, est=4.43263836563413, details={'was_impossible': False}),
#  Prediction(uid=1237, iid=1929, r_ui=4.0, est=4.38875702875694, details={'was_impossible': False}),
#  Prediction(uid=618, iid=2202, r_ui=5.0, est=4.556836709966573, details={'was_impossible': False}),
#  Prediction(uid=1475, iid=2217, r_ui=5.0, est=4.643591342088094, details={'was_impossible': False}),
#  Prediction(uid=141, iid=1862, r_ui=5.0, est=4.567614361691557, details={'was_impossible': False}),
#  Prediction(uid=1332, iid=1964, r_ui=5.0, est=4.556660974362068, details={'was_impossible': False}),
#  Prediction(uid=202, iid=2042, r_ui=4.0, est=4.108153900380244, details={'was_impossible': False}),
#  Prediction(uid=905, iid=368, r_ui=5.0, est=4.239435983624306, details={'was_impossible': False}),
#  Prediction(uid=438, iid=2187, r_ui=4.0, est=4.284388836362424, details={'was_impossible': False}),
#  Prediction(uid=1283, iid=2166, r_ui=3.0, est=4.754192992719806, details={'was_impossible': False}),
#  Prediction(uid=810, iid=2580, r_ui=4.0, est=4.265434350771153, details={'was_impossible': False}),
#  Prediction(uid=849, iid=2432, r_ui=1.0, est=3.7721672341760555, details={'was_impossible': False}),
#  Prediction(uid=419, iid=2555, r_ui=5.0, est=4.581697069414725, details={'was_impossible': False}),
#  Prediction(uid=506, iid=170, r_ui=5.0, est=4.560088404290678, details={'was_impossible': False}),
#  Prediction(uid=50, iid=576, r_ui=5.0, est=4.628599776573488, details={'was_impossible': False}),
#  Prediction(uid=925, iid=1810, r_ui=1.0, est=3.6551537222930555, details={'was_impossible': False}),
#  Prediction(uid=474, iid=2779, r_ui=5.0, est=4.204776106886927, details={'was_impossible': False}),
#  Prediction(uid=205, iid=65, r_ui=5.0, est=4.456468910212226, details={'was_impossible': False}),
#  Prediction(uid=991, iid=1133, r_ui=5.0, est=4.715042543159286, details={'was_impossible': False}),
#  Prediction(uid=888, iid=813, r_ui=5.0, est=4.709137152730285, details={'was_impossible': False}),
#  Prediction(uid=525, iid=176, r_ui=5.0, est=4.358753077010233, details={'was_impossible': False}),
#  Prediction(uid=830, iid=2901, r_ui=5.0, est=4.524495929070078, details={'was_impossible': False}),
#  Prediction(uid=976, iid=2941, r_ui=4.0, est=4.331099513483348, details={'was_impossible': False}),
#  Prediction(uid=634, iid=1796, r_ui=5.0, est=4.602827018925156, details={'was_impossible': False}),
#  Prediction(uid=751, iid=2672, r_ui=5.0, est=4.401901217999534, details={'was_impossible': False}),
#  Prediction(uid=354, iid=3016, r_ui=5.0, est=4.485590063262618, details={'was_impossible': False}),
#  Prediction(uid=100, iid=339, r_ui=5.0, est=4.231688060586748, details={'was_impossible': False}),
#  Prediction(uid=1542, iid=2639, r_ui=1.0, est=4.143417827259325, details={'was_impossible': False}),
#  Prediction(uid=167, iid=2672, r_ui=3.0, est=4.754356592707199, details={'was_impossible': False}),
#  Prediction(uid=883, iid=2798, r_ui=5.0, est=4.61235417329835, details={'was_impossible': False}),
#  Prediction(uid=1555, iid=2895, r_ui=5.0, est=4.215219354996964, details={'was_impossible': False}),
#  Prediction(uid=890, iid=2013, r_ui=4.0, est=4.743407077742807, details={'was_impossible': False}),
#  Prediction(uid=895, iid=1570, r_ui=5.0, est=4.410887106140868, details={'was_impossible': False}),
#  Prediction(uid=54, iid=2824, r_ui=5.0, est=3.947192391374686, details={'was_impossible': False}),
#  Prediction(uid=755, iid=1030, r_ui=4.0, est=4.738448248465778, details={'was_impossible': False}),
#  Prediction(uid=198, iid=2821, r_ui=3.0, est=4.035939842990921, details={'was_impossible': False}),
#  Prediction(uid=1032, iid=1497, r_ui=5.0, est=4.733514728237751, details={'was_impossible': False}),
#  Prediction(uid=642, iid=1029, r_ui=4.0, est=4.444868929245219, details={'was_impossible': False}),
#  Prediction(uid=1172, iid=3056, r_ui=4.0, est=4.414235245193067, details={'was_impossible': False}),
#  Prediction(uid=1175, iid=2229, r_ui=5.0, est=4.640228240331434, details={'was_impossible': False}),
#  Prediction(uid=1304, iid=1313, r_ui=5.0, est=4.533362684208443, details={'was_impossible': False}),
#  Prediction(uid=1148, iid=1173, r_ui=4.0, est=4.7662021189815285, details={'was_impossible': False}),
#  Prediction(uid=122, iid=780, r_ui=4.0, est=4.347208694431486, details={'was_impossible': False}),
#  Prediction(uid=408, iid=613, r_ui=4.0, est=4.4539903353292924, details={'was_impossible': False}),
#  Prediction(uid=881, iid=1832, r_ui=5.0, est=4.480198254694546, details={'was_impossible': False}),
#  Prediction(uid=589, iid=1070, r_ui=5.0, est=4.500090835203907, details={'was_impossible': False}),
#  Prediction(uid=1294, iid=690, r_ui=5.0, est=4.138165461637543, details={'was_impossible': False}),
#  Prediction(uid=948, iid=828, r_ui=5.0, est=4.523534533588764, details={'was_impossible': False}),
# ...
#  Prediction(uid=710, iid=2059, r_ui=4.0, est=4.325303437174532, details={'was_impossible': False}),
#  Prediction(uid=347, iid=2439, r_ui=4.0, est=4.528512531604804, details={'was_impossible': False}),
#  Prediction(uid=866, iid=2024, r_ui=5.0, est=4.554503276594532, details={'was_impossible': False}),
#  Prediction(uid=528, iid=2319, r_ui=5.0, est=4.250109116837539, details={'was_impossible': False}),
#  Prediction(uid=288, iid=183, r_ui=4.0, est=4.574463410460495, details={'was_impossible': False}),
#  Prediction(uid=1458, iid=1028, r_ui=5.0, est=4.447501222424306, details={'was_impossible': False}),
#  Prediction(uid=1167, iid=2058, r_ui=4.0, est=4.347194494726008, details={'was_impossible': False}),
#  Prediction(uid=863, iid=842, r_ui=2.0, est=4.125571309850918, details={'was_impossible': False}),
#  Prediction(uid=1374, iid=826, r_ui=5.0, est=4.266905271602585, details={'was_impossible': False}),
#  Prediction(uid=1378, iid=1944, r_ui=5.0, est=4.792350837440505, details={'was_impossible': False}),
#  Prediction(uid=1093, iid=2928, r_ui=5.0, est=4.376767884700421, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3056, r_ui=5.0, est=4.687047851084078, details={'was_impossible': False}),
#  Prediction(uid=1100, iid=1277, r_ui=5.0, est=4.3617891274027345, details={'was_impossible': False}),
#  Prediction(uid=62, iid=811, r_ui=5.0, est=4.649585385813267, details={'was_impossible': False}),
#  Prediction(uid=943, iid=778, r_ui=5.0, est=4.51838037720897, details={'was_impossible': False}),
#  Prediction(uid=549, iid=2219, r_ui=5.0, est=4.7763888652440345, details={'was_impossible': False}),
#  Prediction(uid=975, iid=963, r_ui=5.0, est=4.425520835776217, details={'was_impossible': False}),
#  Prediction(uid=1257, iid=1539, r_ui=4.0, est=4.652968603368894, details={'was_impossible': False}),
#  Prediction(uid=1208, iid=1070, r_ui=1.0, est=3.785837199657594, details={'was_impossible': False}),
#  Prediction(uid=1180, iid=1680, r_ui=5.0, est=4.096057442211839, details={'was_impossible': False}),
#  Prediction(uid=600, iid=1364, r_ui=2.0, est=4.075784985758029, details={'was_impossible': False}),
#  Prediction(uid=908, iid=1895, r_ui=4.0, est=3.919942171873336, details={'was_impossible': False}),
#  Prediction(uid=737, iid=2321, r_ui=3.0, est=3.941546573356276, details={'was_impossible': False}),
#  Prediction(uid=937, iid=1539, r_ui=5.0, est=4.931481621264967, details={'was_impossible': False}),
#  Prediction(uid=417, iid=508, r_ui=5.0, est=4.343549150413752, details={'was_impossible': False}),
#  Prediction(uid=372, iid=213, r_ui=4.0, est=4.765980076324135, details={'was_impossible': False}),
#  Prediction(uid=813, iid=835, r_ui=5.0, est=4.449689386862589, details={'was_impossible': False}),
#  Prediction(uid=754, iid=1797, r_ui=5.0, est=4.790982098574327, details={'was_impossible': False}),
#  Prediction(uid=1420, iid=1095, r_ui=5.0, est=4.307930086072958, details={'was_impossible': False}),
#  Prediction(uid=285, iid=88, r_ui=1.0, est=4.363206650425738, details={'was_impossible': False}),
#  Prediction(uid=958, iid=2838, r_ui=5.0, est=4.627642580469813, details={'was_impossible': False}),
#  Prediction(uid=360, iid=632, r_ui=5.0, est=3.919029354149011, details={'was_impossible': False}),
#  Prediction(uid=1553, iid=1833, r_ui=5.0, est=4.458075304882441, details={'was_impossible': False}),
#  Prediction(uid=676, iid=1556, r_ui=5.0, est=4.565956710274388, details={'was_impossible': False}),
#  Prediction(uid=228, iid=1804, r_ui=4.0, est=4.474088835944775, details={'was_impossible': False}),
#  Prediction(uid=753, iid=2998, r_ui=5.0, est=4.378489748823339, details={'was_impossible': False}),
#  Prediction(uid=807, iid=2959, r_ui=5.0, est=4.363120928138827, details={'was_impossible': False}),
#  Prediction(uid=1348, iid=789, r_ui=5.0, est=4.695368893824171, details={'was_impossible': False}),
#  Prediction(uid=183, iid=844, r_ui=5.0, est=4.5246366754685, details={'was_impossible': False}),
#  Prediction(uid=1211, iid=1809, r_ui=2.0, est=3.67075137126175, details={'was_impossible': False}),
#  Prediction(uid=543, iid=187, r_ui=2.0, est=4.363782905803574, details={'was_impossible': False}),
#  Prediction(uid=1017, iid=1764, r_ui=5.0, est=4.325786476778709, details={'was_impossible': False}),
#  Prediction(uid=105, iid=1571, r_ui=5.0, est=4.445877281511635, details={'was_impossible': False}),
#  Prediction(uid=351, iid=112, r_ui=3.0, est=4.46486433634296, details={'was_impossible': False}),
#  Prediction(uid=1350, iid=790, r_ui=5.0, est=4.652986956800417, details={'was_impossible': False}),
#  Prediction(uid=949, iid=399, r_ui=4.0, est=4.83733176207997, details={'was_impossible': False}),
#  Prediction(uid=466, iid=2673, r_ui=5.0, est=3.8266924531913027, details={'was_impossible': False}),
#  Prediction(uid=280, iid=800, r_ui=5.0, est=4.719989910766483, details={'was_impossible': False}),
#  Prediction(uid=922, iid=978, r_ui=4.0, est=4.305005703166054, details={'was_impossible': False}),
#  Prediction(uid=837, iid=935, r_ui=5.0, est=4.785993809176817, details={'was_impossible': False}),
#  Prediction(uid=1534, iid=1348, r_ui=5.0, est=4.510574007937443, details={'was_impossible': False}),
#  Prediction(uid=1531, iid=2305, r_ui=5.0, est=4.6763974899359875, details={'was_impossible': False}),
#  Prediction(uid=1240, iid=2414, r_ui=5.0, est=4.420725371002601, details={'was_impossible': False}),
#  Prediction(uid=597, iid=1579, r_ui=5.0, est=4.557999631477876, details={'was_impossible': False}),
#  Prediction(uid=514, iid=1122, r_ui=4.0, est=3.821587352617278, details={'was_impossible': False}),
#  Prediction(uid=720, iid=257, r_ui=5.0, est=4.535603971401564, details={'was_impossible': False}),
#  Prediction(uid=1334, iid=2388, r_ui=5.0, est=4.4176750388341395, details={'was_impossible': False}),
#  Prediction(uid=413, iid=2282, r_ui=5.0, est=4.501397179021984, details={'was_impossible': False}),
#  Prediction(uid=13, iid=1209, r_ui=5.0, est=4.412426543252767, details={'was_impossible': False}),
#  Prediction(uid=1456, iid=1370, r_ui=5.0, est=4.4085551504890255, details={'was_impossible': False}),
#  Prediction(uid=1524, iid=2398, r_ui=4.0, est=4.486747672658191, details={'was_impossible': False}),
#  Prediction(uid=1165, iid=1099, r_ui=4.0, est=4.471606247461228, details={'was_impossible': False}),
#  Prediction(uid=1147, iid=1663, r_ui=5.0, est=4.386812223486681, details={'was_impossible': False}),
#  Prediction(uid=1296, iid=1975, r_ui=3.0, est=4.410375224396908, details={'was_impossible': False}),
#  Prediction(uid=464, iid=653, r_ui=5.0, est=4.696173643998249, details={'was_impossible': False}),
#  Prediction(uid=952, iid=2486, r_ui=5.0, est=4.108017043949332, details={'was_impossible': False}),
#  Prediction(uid=303, iid=652, r_ui=5.0, est=4.831416286649042, details={'was_impossible': False}),
#  Prediction(uid=155, iid=2462, r_ui=5.0, est=4.767514177911028, details={'was_impossible': False}),
#  Prediction(uid=853, iid=1826, r_ui=5.0, est=4.622834124244482, details={'was_impossible': False}),
#  Prediction(uid=807, iid=311, r_ui=5.0, est=4.5932643812541025, details={'was_impossible': False}),
#  Prediction(uid=1485, iid=2072, r_ui=5.0, est=4.479208714643096, details={'was_impossible': False}),
#  Prediction(uid=1100, iid=508, r_ui=5.0, est=4.565068402233213, details={'was_impossible': False}),
#  Prediction(uid=677, iid=1195, r_ui=5.0, est=4.371422665919928, details={'was_impossible': False}),
#  Prediction(uid=956, iid=1442, r_ui=4.0, est=4.389863170368723, details={'was_impossible': False}),
#  Prediction(uid=1578, iid=1970, r_ui=5.0, est=4.6058974845216705, details={'was_impossible': False}),
#  Prediction(uid=1088, iid=2793, r_ui=5.0, est=4.5861747196945215, details={'was_impossible': False}),
#  Prediction(uid=1072, iid=1902, r_ui=5.0, est=4.856043096007951, details={'was_impossible': False}),
#  Prediction(uid=22, iid=600, r_ui=4.0, est=4.370016687256859, details={'was_impossible': False}),
#  Prediction(uid=609, iid=2364, r_ui=5.0, est=4.432054123139105, details={'was_impossible': False}),
#  Prediction(uid=1033, iid=1322, r_ui=5.0, est=4.164495089567064, details={'was_impossible': False}),
#  Prediction(uid=531, iid=641, r_ui=4.0, est=4.282316431336423, details={'was_impossible': False}),
#  Prediction(uid=1163, iid=565, r_ui=5.0, est=4.658249166182812, details={'was_impossible': False}),
#  Prediction(uid=784, iid=2084, r_ui=5.0, est=4.871112768363646, details={'was_impossible': False}),
#  Prediction(uid=1510, iid=2816, r_ui=4.0, est=4.165384945911828, details={'was_impossible': False}),
#  Prediction(uid=1115, iid=519, r_ui=5.0, est=4.973570503727226, details={'was_impossible': False}),
#  Prediction(uid=954, iid=1122, r_ui=5.0, est=4.1694673012039605, details={'was_impossible': False}),
#  Prediction(uid=1338, iid=770, r_ui=5.0, est=4.223769558630381, details={'was_impossible': False}),
#  Prediction(uid=247, iid=1137, r_ui=2.0, est=4.300345018230629, details={'was_impossible': False}),
#  Prediction(uid=279, iid=3139, r_ui=4.0, est=4.432989579620074, details={'was_impossible': False}),
#  Prediction(uid=1212, iid=1563, r_ui=5.0, est=4.422915280141654, details={'was_impossible': False}),
#  Prediction(uid=275, iid=2646, r_ui=5.0, est=4.70673300947702, details={'was_impossible': False}),
#  Prediction(uid=345, iid=1970, r_ui=5.0, est=4.590055606544216, details={'was_impossible': False}),
#  Prediction(uid=770, iid=2492, r_ui=4.0, est=4.109818355936373, details={'was_impossible': False}),
#  Prediction(uid=1046, iid=477, r_ui=2.0, est=4.0333800303236735, details={'was_impossible': False}),
#  Prediction(uid=1307, iid=986, r_ui=4.0, est=4.327359717064669, details={'was_impossible': False}),
#  Prediction(uid=847, iid=2312, r_ui=5.0, est=4.357285464107566, details={'was_impossible': False}),
#  Prediction(uid=1127, iid=3110, r_ui=5.0, est=4.615725127004305, details={'was_impossible': False}),
#  Prediction(uid=729, iid=2128, r_ui=4.0, est=4.459448539010852, details={'was_impossible': False}),
#  Prediction(uid=1070, iid=1448, r_ui=4.0, est=4.2971879495918275, details={'was_impossible': False}),
#  Prediction(uid=1105, iid=512, r_ui=5.0, est=4.752177619297425, details={'was_impossible': False}),
#  Prediction(uid=475, iid=1473, r_ui=5.0, est=4.594140833508956, details={'was_impossible': False}),
#  Prediction(uid=369, iid=122, r_ui=5.0, est=4.35936237684479, details={'was_impossible': False}),
#  Prediction(uid=1446, iid=989, r_ui=4.0, est=4.276726198821713, details={'was_impossible': False}),
#  Prediction(uid=459, iid=891, r_ui=5.0, est=4.561030168474673, details={'was_impossible': False}),
#  Prediction(uid=710, iid=846, r_ui=5.0, est=4.493538333041249, details={'was_impossible': False}),
#  Prediction(uid=39, iid=227, r_ui=3.0, est=4.176121204712886, details={'was_impossible': False}),
#  Prediction(uid=665, iid=2819, r_ui=5.0, est=4.919299474845409, details={'was_impossible': False}),
#  Prediction(uid=193, iid=531, r_ui=5.0, est=4.925237236920208, details={'was_impossible': False}),
#  Prediction(uid=1377, iid=897, r_ui=5.0, est=4.761016431258715, details={'was_impossible': False}),
#  Prediction(uid=175, iid=331, r_ui=3.0, est=4.354579326883085, details={'was_impossible': False}),
#  Prediction(uid=727, iid=2290, r_ui=5.0, est=4.453241754491865, details={'was_impossible': False}),
#  Prediction(uid=200, iid=522, r_ui=5.0, est=4.747196745609575, details={'was_impossible': False}),
#  Prediction(uid=1367, iid=1902, r_ui=5.0, est=4.578162780408908, details={'was_impossible': False}),
#  Prediction(uid=608, iid=1780, r_ui=4.0, est=4.406672424195814, details={'was_impossible': False}),
#  Prediction(uid=749, iid=1705, r_ui=3.0, est=4.2800980486584175, details={'was_impossible': False}),
#  Prediction(uid=528, iid=347, r_ui=1.0, est=4.43402551614521, details={'was_impossible': False}),
#  Prediction(uid=503, iid=3103, r_ui=3.0, est=4.5032549107991935, details={'was_impossible': False}),
#  Prediction(uid=966, iid=1392, r_ui=3.0, est=3.8933009601462425, details={'was_impossible': False}),
#  Prediction(uid=272, iid=2095, r_ui=5.0, est=4.777130762349037, details={'was_impossible': False}),
#  Prediction(uid=1270, iid=2801, r_ui=4.0, est=4.246845756762963, details={'was_impossible': False}),
#  Prediction(uid=1207, iid=1997, r_ui=5.0, est=4.838816880252033, details={'was_impossible': False}),
#  Prediction(uid=1052, iid=829, r_ui=5.0, est=4.480299789582488, details={'was_impossible': False}),
#  Prediction(uid=1452, iid=3142, r_ui=3.0, est=4.090885681814143, details={'was_impossible': False}),
#  Prediction(uid=1102, iid=3064, r_ui=5.0, est=4.504145417353267, details={'was_impossible': False}),
#  Prediction(uid=891, iid=1034, r_ui=5.0, est=4.451832484001117, details={'was_impossible': False}),
#  Prediction(uid=127, iid=3130, r_ui=5.0, est=3.9798213802659816, details={'was_impossible': False}),
#  Prediction(uid=935, iid=1681, r_ui=5.0, est=4.441513487712184, details={'was_impossible': False}),
#  Prediction(uid=1023, iid=2700, r_ui=5.0, est=4.618755071395229, details={'was_impossible': False}),
#  Prediction(uid=950, iid=2438, r_ui=5.0, est=4.445292475642142, details={'was_impossible': False}),
#  Prediction(uid=431, iid=1535, r_ui=5.0, est=4.770586902674106, details={'was_impossible': False}),
#  Prediction(uid=268, iid=1652, r_ui=4.0, est=4.200536772126295, details={'was_impossible': False}),
#  Prediction(uid=1065, iid=491, r_ui=4.0, est=4.224237643972, details={'was_impossible': False}),
#  Prediction(uid=91, iid=28, r_ui=4.0, est=4.597719558184169, details={'was_impossible': False}),
#  Prediction(uid=1251, iid=1538, r_ui=1.0, est=3.6349096755656807, details={'was_impossible': False}),
#  Prediction(uid=483, iid=1958, r_ui=4.0, est=4.295317628467548, details={'was_impossible': False}),
#  Prediction(uid=665, iid=2558, r_ui=5.0, est=4.489457470475408, details={'was_impossible': False}),
#  Prediction(uid=796, iid=2366, r_ui=5.0, est=4.685169012964409, details={'was_impossible': False}),
#  Prediction(uid=1352, iid=1864, r_ui=3.0, est=4.491271394429244, details={'was_impossible': False}),
#  Prediction(uid=993, iid=2142, r_ui=5.0, est=4.476979917345328, details={'was_impossible': False}),
#  Prediction(uid=514, iid=478, r_ui=3.0, est=3.9320141025331687, details={'was_impossible': False}),
#  Prediction(uid=470, iid=156, r_ui=5.0, est=4.0621459806527636, details={'was_impossible': False}),
#  Prediction(uid=270, iid=2525, r_ui=4.0, est=4.171252136211217, details={'was_impossible': False}),
#  Prediction(uid=359, iid=2027, r_ui=5.0, est=4.485839866893203, details={'was_impossible': False}),
#  Prediction(uid=100, iid=31, r_ui=5.0, est=4.34531034483796, details={'was_impossible': False}),
#  Prediction(uid=1221, iid=617, r_ui=4.0, est=4.387650405719952, details={'was_impossible': False}),
#  Prediction(uid=146, iid=1043, r_ui=5.0, est=4.6542668279421715, details={'was_impossible': False}),
#  Prediction(uid=1505, iid=1158, r_ui=1.0, est=4.311039647652719, details={'was_impossible': False}),
#  Prediction(uid=942, iid=2619, r_ui=5.0, est=4.712654489256772, details={'was_impossible': False}),
#  Prediction(uid=54, iid=1682, r_ui=4.0, est=4.122047253458575, details={'was_impossible': False}),
#  Prediction(uid=61, iid=1306, r_ui=5.0, est=4.562068895485808, details={'was_impossible': False}),
#  Prediction(uid=1417, iid=913, r_ui=5.0, est=4.081794706272409, details={'was_impossible': False}),
#  Prediction(uid=1129, iid=600, r_ui=5.0, est=4.684200946958548, details={'was_impossible': False}),
#  Prediction(uid=706, iid=1128, r_ui=4.0, est=3.811309717216626, details={'was_impossible': False}),
#  Prediction(uid=1490, iid=2934, r_ui=2.0, est=4.105070978090983, details={'was_impossible': False}),
#  Prediction(uid=633, iid=731, r_ui=5.0, est=4.653667628191917, details={'was_impossible': False}),
#  Prediction(uid=197, iid=971, r_ui=5.0, est=4.327619602182343, details={'was_impossible': False}),
#  Prediction(uid=1504, iid=2729, r_ui=5.0, est=4.664165624746634, details={'was_impossible': False}),
#  Prediction(uid=1116, iid=1330, r_ui=5.0, est=4.675550980726092, details={'was_impossible': False}),
#  Prediction(uid=854, iid=625, r_ui=4.0, est=4.497087351503902, details={'was_impossible': False}),
#  ...]

# %%
def get_Iu(uid):
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError: # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    try: 
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:
        return 0

# %%
df = pd.DataFrame(predictions, columns=['user_int_id', 'prod_int_id', 'rating', 'predicted_rating', 'details'])

# %%
df['items_rated_by_user'] = df.user_int_id.apply(get_Iu)
df['num_ratings_for_item'] = df.prod_int_id.apply(get_Ui)

# %%
df['error'] = abs(df.predicted_rating - df.rating)
df
# Out:
#       user_int_id  prod_int_id  rating  predicted_rating  \
# 0             168           56     4.0          4.391373
# 1             717          564     5.0          4.432421
# 2             509          214     4.0          4.714995
# 3             684         1684     5.0          4.181862
# 4              36         2954     4.0          4.395872
# ...           ...          ...     ...               ...
# 4056         1431         1611     3.0          4.306039
# 4057          315         2709     5.0          4.742744
# 4058          821         1242     1.0          4.187865
# 4059         1336          795     3.0          4.330160
# 4060          595         1825     5.0          4.595358
#
#                         details  items_rated_by_user  num_ratings_per_item  \
# 0     {'was_impossible': False}                   23                     2
# 1     {'was_impossible': False}                    8                     2
# 2     {'was_impossible': False}                    7                     5
# 3     {'was_impossible': False}                   13                     4
# 4     {'was_impossible': False}                   23                     2
# ...                         ...                  ...                   ...
# 4056  {'was_impossible': False}                    2                     4
# 4057  {'was_impossible': False}                   14                     3
# 4058  {'was_impossible': False}                   10                     0
# 4059  {'was_impossible': False}                    9                     9
# 4060  {'was_impossible': False}                    8                     4
#
#          error
# 0     0.391373
# 1     0.567579
# 2     0.714995
# 3     0.818138
# 4     0.395872
# ...        ...
# 4056  1.306039
# 4057  0.257256
# 4058  3.187865
# 4059  1.330160
# 4060  0.404642
#
# [4061 rows x 8 columns]

# %%
df2 = df1.drop(columns = ['overall', 'user_int_id'], axis = 1)

# %%
df2 = df2.drop_duplicates().reset_index(drop=True)

# %%
result = pd.merge(df,df2, on='prod_int_id').drop('details',axis=1)

# %% [markdown]
# ### Best predictions

# %%
best_predictions = result.sort_values(by='error')[:10]
best_predictions
# Out:
#       user_int_id  prod_int_id  rating  predicted_rating  items_rated_by_user  \
# 2805          524         1590     5.0               5.0                   13
# 2441          595          211     5.0               5.0                    8
# 627           302          653     5.0               5.0                   10
# 141          1273          776     5.0               5.0                   10
# 2470         1422         3007     5.0               5.0                   15
# 2472          193         3007     5.0               5.0                   17
# 2473          338         3007     5.0               5.0                    9
# 364           287         1281     5.0               5.0                    8
# 2485          883         2375     5.0               5.0                   19
# 2356          308         1272     5.0               5.0                   43
#
#       num_ratings_per_item  error  \
# 2805                    28    0.0
# 2441                    18    0.0
# 627                     40    0.0
# 141                     27    0.0
# 2470                    21    0.0
# 2472                    21    0.0
# 2473                    21    0.0
# 364                     22    0.0
# 2485                    13    0.0
# 2356                    21    0.0
#
#                                                   title
# 2805  Belkin 8-Outlet Power Strip Surge Protector wi...
# 2441  BlueRigger High Speed HDMI to DVI Adapter Cabl...
# 627   AmazonBasics USB 2.0 Extension Cable - A-Male ...
# 141   Tripp Lite Isobar 2 Outlet Surge Protector Pow...
# 2470  Crucial 2GB Single DDR3/DDR3L 1600 MT/S (PC3-1...
# 2472  Crucial 2GB Single DDR3/DDR3L 1600 MT/S (PC3-1...
# 2473  Crucial 2GB Single DDR3/DDR3L 1600 MT/S (PC3-1...
# 364   Hosa CPR-203 Dual 1/4&quot; TS to Dual RCA Ste...
# 2485  Belkin 6-Outlet Pivot-Plug Wall Mount Power St...
# 2356  NETGEAR 8-Port Fast Ethernet Unmanaged Switch,...

# %% [markdown]
# ### Worst predictions

# %%
worst_predictions = result.sort_values(by='error')[-10:]
worst_predictions
# Out:
#       user_int_id  prod_int_id  rating  predicted_rating  items_rated_by_user  \
# 3005         1442          972     1.0          4.556105                    8
# 3874          630         2180     1.0          4.560319                    4
# 2370          157           53     1.0          4.572110                    4
# 2167          955         1997     1.0          4.573888                    9
# 3111          759         1609     1.0          4.603056                    8
# 1551          937          739     1.0          4.626104                   16
# 93            437         1679     1.0          4.627656                    9
# 2514          246          994     1.0          4.631199                   10
# 283          1546         1365     1.0          4.686406                    2
# 3250          621         3046     1.0          4.813808                    6
#
#       num_ratings_per_item     error  \
# 3005                     0  3.556105
# 3874                     1  3.560319
# 2370                     6  3.572110
# 2167                    17  3.573888
# 3111                     0  3.603056
# 1551                     6  3.626104
# 93                      11  3.627656
# 2514                     0  3.631199
# 283                      5  3.686406
# 3250                     7  3.813808
#
#                                                   title
# 3005  JLab JBuds J5M Metal Earbuds Style Headphones ...
# 3874  BUFFALO AirStation HighPower N300 Gigabit Wire...
# 2370  Snap-N-Store CD Storage Box, 13.25 x 5.125 x 5...
# 2167  SanDisk Extreme PRO 32GB up to 95MB/s UHS-I/U3...
# 3111          PQI USB 2.0 CompactFlash (CF) Card Reader
# 1551      iNassen Compatible Earphone Adapter Headphone
# 93    Monoprice 6-Feet USB 2.0 A Male to A Female Ex...
# 2514           Asus ProArt PA248Q 24.1 Inch LED Monitor
# 283       Logitech S150 USB Speakers with Digital Sound
# 3250  Logitech K360 Wireless USB Desktop Keyboard &m...
